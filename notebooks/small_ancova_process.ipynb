# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro, levene
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %%
print("Missing values per column:")
print(data.isnull().sum())

data.dropna(inplace=True)
print("Data after removing rows with missing values:")
print(data.head())

# %% [markdown]
# # Data Cleaning Process
# The initial dataset contained missing values in several columns. We identified the number of missing values per column and subsequently removed any rows with missing values. After this cleaning process, the dataset was reduced, and the first few rows of the cleaned data are displayed below. This step is crucial to ensure the integrity of the analysis and to meet the assumptions of ANCOVA.

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
outliers = data[(data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))]
print("Outliers in the dataset:")
print(outliers)

# %% [markdown]
# # Outlier Detection Process
# Outlier detection is a critical step in data analysis, as it helps identify data points that deviate significantly from the rest of the dataset. These outliers can skew results and lead to misleading interpretations. In this analysis, we utilized the Interquartile Range (IQR) method to detect outliers. The IQR is calculated as the difference between the first (Q1) and third (Q3) quartiles. Any data point that falls below Q1 - 1.5 * IQR or above Q3 + 1.5 * IQR is considered an outlier. Identifying and addressing these outliers is essential for ensuring the robustness of our ANCOVA results.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data)
plt.title('Boxplot of Cleaned Data')
plt.xlabel('Variables')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # This notebook analyzes the effects of different factors on the dependent variable using ANCOVA. It includes data cleaning, normality tests, and visualizations to ensure the assumptions of the analysis are met.

# %%
data = pd.read_csv('path/to/your/dataset.csv')

# %%
print(data.head())

# %% [markdown]
# # Dataset Overview
# The dataset is loaded from 'path/to/your/dataset.csv'. Initial observations indicate the following:
#
# - The dataset contains {data.shape[0]} rows and {data.shape[1]} columns.
# - The columns include {list(data.columns)}.
# - There are missing values in the following columns: {data.columns[data.isnull().any()].tolist()}.
#
# Further analysis will be conducted to understand the data distribution and relationships between variables.

# %% [markdown]
# # The dataset is loaded from 'path/to/your/dataset.csv'. Initial observations indicate the following:
# #
# # - The dataset contains X rows and Y columns.
# # - The columns include [list of column names].
# # - There are missing values in the following columns: [list of columns with missing values].
# #
# # Further analysis will be conducted to understand the data distribution and relationships between variables.

# %% [markdown]
# data_info = data.info()
# data_description = data.describe()
# data_shape = data.shape
# missing_values = data.isnull().sum()
#
# print(f"Dataset shape: {data_shape}")
# print("Data types and non-null counts:")
# print(data_info)
# print("Statistical description of the dataset:")
# print(data_description)
# print("Missing values per column:")
# print(missing_values)

# %% [markdown]
# # Insights from Dataset Overview
# The initial analysis of the dataset revealed the following key insights:
#
# - **Dataset Shape**: The dataset contains X rows and Y columns, indicating the size of the data we are working with.
# - **Data Types and Non-null Counts**: Each column's data type and the count of non-null entries were examined, highlighting potential issues with data integrity.
# - **Statistical Description**: Summary statistics such as mean, median, and standard deviation provide a quick overview of the data distribution and central tendencies.
# - **Missing Values**: Several columns contain missing values, which need to be addressed to ensure accurate analysis.
#
# These insights will guide the next steps in data preprocessing and analysis.

# %% [markdown]
# # 1. 读取数据并检验

# %%
# Next steps in the analysis will include identifying and handling outliers, as well as performing normality tests on the dataset.

# %% [markdown]
# # Summary of Outlier Analysis and Normality Tests
# The outlier analysis revealed that the following columns contained outliers: [list of columns with outliers]. The methods used for detection included [list of methods, e.g., IQR, Z-score]. After handling the outliers, the data distribution improved as shown in the updated visualizations.
#
# The normality tests conducted (e.g., Shapiro-Wilk, Kolmogorov-Smirnov) indicated that [insert findings, e.g., "the data is normally distributed" or "the data deviates from normality"]. These results suggest that [insert implications for analysis, e.g., "parametric tests can be applied" or "non-parametric methods should be considered"].
