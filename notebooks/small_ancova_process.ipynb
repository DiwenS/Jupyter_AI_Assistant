# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import shapiro, levene
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %% [markdown]
# # Data Loading Process and Initial Observations
#
# 1. **Load the Dataset**: We will load the dataset from a specified file path.
# 2. **Initial Data Overview**: Display the first few rows of the dataset to understand its structure and contents.
#
# ```python
# # Load the dataset
# data = pd.read_csv('path/to/your/dataset.csv')
#
# # Initial data overview
# print("First few rows of the dataset:")
# print(data.head())
# ```

# %% [markdown]
# # Data Cleaning Steps
#
# 1. **Check for Missing Values**: We examined the dataset for any missing values in each column.
# 2. **Handle Missing Values**: Rows with missing values were removed to ensure the integrity of the analysis.
# 3. **Data Overview**: The first few rows of the cleaned dataset were displayed to confirm the changes.

# %%
print("Data types of the cleaned dataset:")
print(data.dtypes)

# %% [markdown]
# # 1. 读取数据并检验

# %% [markdown]
# # Analysis Plan Outline
#
# 1. **Objective**: Determine the effect of the independent variable(s) on the dependent variable using ANCOVA.
# 2. **Data Preparation**:
#    - Check for missing values and handle them appropriately.
#    - Ensure data types are correct for analysis.
# 3. **Assumptions Check**:
#    - Normality of residuals (Shapiro-Wilk test).
#    - Homogeneity of variances (Levene's test).
# 4. **Model Specification**:
#    - Define the ANCOVA model using the appropriate formula.
# 5. **Model Fitting**:
#    - Fit the ANCOVA model using statsmodels.
# 6. **Results Interpretation**:
#    - Analyze the output of the model summary.
#    - Check for significant effects and interpret coefficients.
# 7. **Post-hoc Analysis** (if necessary):
#    - Conduct post-hoc tests to explore differences between groups.
# 8. **Visualization**:
#    - Create plots to visualize the results and assumptions.
